# %% [markdown]
# <a href="https://colab.research.google.com/github/Kristian209/Data-lit/blob/master/Sent_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install twython
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/c2/b0/a3/5c4b4b87b8c9e4d99f1494a0b471f0134a74e5fb33d426d009
# Successfully built twython
# ...
#     100% |████████████████████████████████| 133kB 4.0MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
consumer_key = 'Io1uDZZbbsJCCyHf3aw1NWHre'
consumer_secret = '6DVTvhIU0AsLfVwNppueDCvyRXW3E6LrrxBYps6AOUNb3yIn6U'
access_token = '1093937831444045824-MfXi4ZzSIoD4yjdbuLfZ7CY9l4Bbco'
access_token_secret = 'gW0w2HYZ0lDn94tdLROXyz4cXJyJX8eLOoQzoKpcNnDgv'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Air Pods', count=200)

data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))

print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @MuhithSamira: Air pods ain’t cutting it. W...
# 1                  @ethnchen sell ur air pods mister
# 2  RT @BoiUAFool: Y do y’all act like air pods co...
# 3  RT @Dmoney3k: Are air pods really worth the mo...
# 4  My sister got some nerve asking for air pods f...
# 5  domu is an hour and a half wait so richard and...
# 6               Are air pods really worth the money?
# 7  Why do people act like air pods are hard to ge...
# 8  Jokes on you I don’t have air pods either http...
# 9  Fam gave me tons of money for my birthday do I...
# 2019-02-09 01:43:04

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()

listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row['Tweets'])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @MuhithSamira: Air pods ain’t cutting it. W...
# 1                   @ethnchen sell ur air pods mister
# 2   RT @BoiUAFool: Y do y’all act like air pods co...
# 3   RT @Dmoney3k: Are air pods really worth the mo...
# 4   My sister got some nerve asking for air pods f...
# 5   domu is an hour and a half wait so richard and...
# 6                Are air pods really worth the money?
# 7   Why do people act like air pods are hard to ge...
# 8   Jokes on you I don’t have air pods either http...
# 9   Fam gave me tons of money for my birthday do I...
# 10  RT @kaydolly_: If you come up to me with air p...
# 11  RT @V_B_information: 身体づくり応援📣\n毎週日曜日〆切。マイプロテイン...
# 12  RT @shortyfromsc: damn i want some air pods now 😢
# 13  Kids: “Mommy why does that man have wires on h...
# 14  RT @SousaSecret: Nigel watch out for the truck...
# 15  The ultimate flex: just wearing air pods to sh...
# ...
